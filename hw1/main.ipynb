# %%
# Notice!
#
# Although this jupyter notebook works, I recommend you to run `main.py` manually.
# On the one hand, I wrote all of this in VSCode on `main.py`, so everythings works better there.
# On the other hand, you can avoid package conflicts by using a virtual environment created according to `requirements.txt`.
#
# `main.py` has a better output format, too.
# Here's what you will get if you run `main.py`:

"""
----------------------------------------------------------------- < Original Data (first 5 rows) > ----------------------------------------------------------------
   Student ID Student Country  Question ID  Type of Answer Question Level       Topic    Subtopic                                           Keywords
0         647         Ireland           77               0          Basic  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
1          41        Portugal           77               1          Basic  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
2         340        Portugal           77               1          Basic  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
3         641           Italy           77               0          Basic  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
4         669        Portugal           77               1          Basic  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...

----------------------------------------------------------------------- < Preprocess Data > -----------------------------------------------------------------------
Dropped 2083 (21%) duplicates, such as:
    Student ID Student Country  Question ID  ...                                Topic                    Subtopic                                           Keywords
28          41        Portugal           79  ...                           Statistics                  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
29          41        Portugal           79  ...                           Statistics                  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
35          57        Portugal           79  ...                           Statistics                  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
36          57        Portugal           79  ...                           Statistics                  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
78         181           Italy           83  ...  Real Functions of a single variable  Domain, Image and Graphics                         Domain,Image of a function

[5 rows x 8 columns]
Found 0 null values in the data, so we do not need to drop any.

---------------------------------------------------------------------------- < Topics > ---------------------------------------------------------------------------
                                  Topic                                           Subtopic                                         Topic Name  Question Count
0                     Analytic Geometry                                  Analytic Geometry                                  Analytic Geometry              40
1                       Complex Numbers                                    Complex Numbers                                    Complex Numbers              52
2                Differential Equations                             Differential Equations                             Differential Equations              33
3                       Differentiation                                        Derivatives                      Differentiation / Derivatives              43
4                       Differentiation                            Partial Differentiation          Differentiation / Partial Differentiation              55
5               Fundamental Mathematics  Algebraic expressions, Equations, and Inequali...  Fundamental Mathematics / Algebraic expression...              38
6               Fundamental Mathematics                                Elementary Geometry      Fundamental Mathematics / Elementary Geometry              46
7                          Graph Theory                                       Graph Theory                                       Graph Theory              38
8                           Integration                                 Definite Integrals                   Integration / Definite Integrals              12
9                           Integration                                 Double Integration                   Integration / Double Integration              10
10                          Integration                             Integration Techniques               Integration / Integration Techniques              32
11                       Linear Algebra                       Eigenvalues and Eigenvectors      Linear Algebra / Eigenvalues and Eigenvectors              38
12                       Linear Algebra                                     Linear Systems                    Linear Algebra / Linear Systems              40
13                       Linear Algebra                             Linear Transformations            Linear Algebra / Linear Transformations              40
14                       Linear Algebra                          Matrices and Determinants         Linear Algebra / Matrices and Determinants              40
15                       Linear Algebra                                      Vector Spaces                     Linear Algebra / Vector Spaces              40
16                    Numerical Methods                                  Numerical Methods                                  Numerical Methods              41
17                         Optimization                                Linear Optimization                 Optimization / Linear Optimization              30
18                         Optimization                             Nonlinear Optimization              Optimization / Nonlinear Optimization              32
19                         Probability                                        Probability                                        Probability               42
20  Real Functions of a single variable                         Domain, Image and Graphics  Real Functions of a single variable / Domain, ...              18
21  Real Functions of a single variable                              Limits and Continuity  Real Functions of a single variable / Limits a...              22
22                           Set Theory                                         Set Theory                                         Set Theory              25
23                           Statistics                                         Statistics                                         Statistics              26

---------------------------------------------------------------- < Student Scores (first 5 rows) > ----------------------------------------------------------------
   Student ID  Percentage  Basic Percentage  Advanced Percentage
0          26   72.463768         72.463768                  NaN
1          28   51.020408         51.020408                  NaN
2          36   51.428571         50.000000            57.142857
3          37   59.375000         57.264957            81.818182
4          41   56.896552         56.603774            60.000000

-------------------------------------------------------------------------- < Statistics > -------------------------------------------------------------------------
                                                           Max        Min         Q1         Q2          Q3       Mean        Std
Percentage                                          100.000000   0.000000  25.000000  45.141066   63.131313  45.357919  26.855631
Basic Percentage                                    100.000000   0.000000  24.242424  42.857143   61.702128  44.180045  27.436532
Advanced Percentage                                 100.000000   0.000000  29.120879  57.142857   71.428571  51.208616  30.669467
Percentage of Analytic Geometry                     100.000000   0.000000  16.071429  42.857143   66.666667  41.863937  30.768153
Percentage of Complex Numbers                       100.000000   0.000000  26.879699  45.490716   71.428571  48.705581  29.912735
Percentage of Differential Equations                100.000000   0.000000   0.000000  57.142857   68.984962  44.963563  37.637283
Percentage of Differentiation / Derivatives          85.714286   0.000000  14.285714  25.000000   52.941176  31.649800  26.250800
Percentage of Differentiation / Partial Differe...  100.000000   0.000000   0.000000   5.555556   23.750000  21.430886  31.228039
Percentage of Fundamental Mathematics / Algebra...  100.000000   0.000000  14.285714  37.087912   50.000000  36.536196  28.407707
Percentage of Fundamental Mathematics / Element...  100.000000   0.000000  22.758621  55.042017   72.857143  49.565951  31.766839
Percentage of Graph Theory                          100.000000   0.000000  28.571429  38.095238   61.278195  44.329574  32.153246
Percentage of Integration / Definite Integrals       85.714286  62.500000  68.303571  74.107143   79.910714  74.107143  16.414979
Percentage of Integration / Double Integration      100.000000   0.000000  37.500000  54.166667   68.750000  52.083333  41.036908
Percentage of Integration / Integration Techniques  100.000000   0.000000   0.000000  28.571429   66.666667  35.254804  35.276878
Percentage of Linear Algebra / Eigenvalues and ...  100.000000   0.000000   0.000000  57.142857  100.000000  52.179636  40.488716
Percentage of Linear Algebra / Linear Systems       100.000000   0.000000  34.459459  57.603687   80.576923  54.806888  33.824266
Percentage of Linear Algebra / Linear Transform...  100.000000   0.000000  25.000000  57.142857   71.428571  51.347286  31.279440
Percentage of Linear Algebra / Matrices and Det...  100.000000   0.000000  26.136364  56.521739   73.214286  51.956994  33.229050
Percentage of Linear Algebra / Vector Spaces        100.000000   0.000000  28.571429  50.000000   66.666667  46.901145  27.444780
Percentage of Numerical Methods                      85.714286   0.000000  36.428571  51.388889   54.384615  45.315222  24.983126
Percentage of Optimization / Linear Optimization    100.000000   0.000000   6.944444  40.811966   88.461538  46.937322  45.721636
Percentage of Optimization / Nonlinear Optimiza...   66.666667   0.000000  28.571429  44.444444   50.000000  36.710758  23.471983
Percentage of Probability                           100.000000   0.000000  17.142857  31.578947   64.285714  41.355263  34.696494
Percentage of Real Functions of a single variab...   85.714286   0.000000  14.285714  37.500000   53.571429  35.801698  28.343626
Percentage of Real Functions of a single variab...  100.000000   0.000000  21.428571  42.857143   58.333333  43.506494  34.537615
Percentage of Set Theory                             85.714286  52.631579  66.729323  71.428571   75.000000  70.300752  13.568599
Percentage of Statistics                            100.000000   0.000000  28.571429  50.000000   64.123377  49.090105  29.167609

--------------------------------------------------------------------------- < Outliers > --------------------------------------------------------------------------
(No outliers in Percentage.)
(No outliers in Basic Percentage.)
(No outliers in Advanced Percentage.)
(No outliers in Percentage of Analytic Geometry.)
(No outliers in Percentage of Complex Numbers.)
(No outliers in Percentage of Differential Equations.)
(No outliers in Percentage of Differentiation / Derivatives.)
--------------------------------------------------------------------------------
Outliers in Percentage of Differentiation / Partial Differentiation:
Q1 = 0.00, Q3 = 23.75, IQR = 23.75, 30 students
55 questions in Differentiation / Partial Differentiation
    Student ID  Percentage of Differentiation / Partial Differentiation
3           37                                          65.625000      
23         155                                          66.666667      
97         483                                          75.000000      
0           26                                         100.000000      
11          71                                         100.000000      
All students:
     Student ID  Percentage of Differentiation / Partial Differentiation
177         751                                           0.000000      
27          165                                           0.000000      
226        1028                                           0.000000      
227        1029                                           0.000000      
225        1026                                           0.000000      
224        1024                                           0.000000      
220        1011                                           0.000000      
178         753                                           0.000000      
232        1038                                           0.000000      
240        1050                                           0.000000      
237        1046                                           0.000000      
234        1043                                           0.000000      
230        1036                                           0.000000      
231        1037                                           0.000000      
229        1034                                           0.000000      
233        1039                                          11.111111      
239        1049                                          13.333333      
238        1047                                          14.285714      
241        1056                                          14.285714      
228        1032                                          14.285714      
199         918                                          20.000000      
236        1045                                          20.000000      
244        1075                                          25.000000      
51          239                                          50.000000      
235        1044                                          53.333333      
3            37                                          65.625000      
23          155                                          66.666667      
97          483                                          75.000000      
11           71                                         100.000000      
0            26                                         100.000000      
--------------------------------------------------------------------------------
(No outliers in Percentage of Fundamental Mathematics / Algebraic expressions, Equations, and Inequalities.)
(No outliers in Percentage of Fundamental Mathematics / Elementary Geometry.)
(No outliers in Percentage of Graph Theory.)
(No outliers in Percentage of Integration / Definite Integrals.)
(No outliers in Percentage of Integration / Double Integration.)
(No outliers in Percentage of Integration / Integration Techniques.)
(No outliers in Percentage of Linear Algebra / Eigenvalues and Eigenvectors.)
(No outliers in Percentage of Linear Algebra / Linear Systems.)
(No outliers in Percentage of Linear Algebra / Linear Transformations.)
(No outliers in Percentage of Linear Algebra / Matrices and Determinants.)
(No outliers in Percentage of Linear Algebra / Vector Spaces.)
--------------------------------------------------------------------------------
Outliers in Percentage of Numerical Methods:
Q1 = 36.43, Q3 = 54.38, IQR = 17.96, 12 students
41 questions in Numerical Methods
     Student ID  Percentage of Numerical Methods
209         973                         0.000000
11           71                        85.714286
All students:
     Student ID  Percentage of Numerical Methods
209         973                         0.000000
364        1538                        11.111111
366        1543                        17.142857
3            37                        42.857143
201         955                        46.000000
198         913                        50.000000
32          175                        52.777778
365        1542                        53.333333
334        1340                        53.846154
212         979                        56.000000
210         974                        75.000000
11           71                        85.714286
--------------------------------------------------------------------------------
(No outliers in Percentage of Optimization / Linear Optimization.)
(No outliers in Percentage of Optimization / Nonlinear Optimization.)
(No outliers in Percentage of Probability .)
(No outliers in Percentage of Real Functions of a single variable / Domain, Image and Graphics.)
(No outliers in Percentage of Real Functions of a single variable / Limits and Continuity.)
--------------------------------------------------------------------------------
Outliers in Percentage of Set Theory:
Q1 = 66.73, Q3 = 75.00, IQR = 8.27, 4 students
25 questions in Set Theory
    Student ID  Percentage of Set Theory
15          85                 52.631579
All students:
     Student ID  Percentage of Set Theory
15           85                 52.631579
0            26                 71.428571
2            36                 71.428571
198         913                 85.714286
--------------------------------------------------------------------------------
(No outliers in Percentage of Statistics.)

---------------------------------------------------------- < Student, Country and Score (first 5 rows) > ----------------------------------------------------------
   Student ID  Total Basic Score  Personal Basic Score  ...  Percentage of Set Theory  Percentage of Statistics  Student Country
0          26                 69                    50  ...                 71.428571                       NaN         Portugal
1          28                 49                    25  ...                       NaN                  0.000000         Portugal
2          36                 28                    14  ...                 71.428571                       NaN         Portugal
3          37                117                    67  ...                       NaN                       NaN         Portugal
4          41                 53                    30  ...                       NaN                 64.285714         Portugal

[5 rows x 83 columns]
/home/nictheboy/Documents/college-ids-hw/hw1/main.py:242: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
  sns.kdeplot(ndarr[country_indices], label=country)
/home/nictheboy/Documents/college-ids-hw/hw1/main.py:242: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
  sns.kdeplot(ndarr[country_indices], label=country)

-------------------------------------------------------------------- < Correlation of Scores > --------------------------------------------------------------------
                         Personal Score  Personal Basic Score  Personal Advanced Score  Country Code
Personal Score                 1.000000              0.951842                 0.631442      0.021222
Personal Basic Score           0.951842              1.000000                 0.363297      0.013948
Personal Advanced Score        0.631442              0.363297                 1.000000      0.029215
Country Code                   0.021222              0.013948                 0.029215      1.000000

----------------------------------------------------------------- < Correlation with Percentage > -----------------------------------------------------------------
Percentage                                                                                    1.000000
Basic Percentage                                                                              0.916512
Percentage of Linear Algebra / Vector Spaces                                                  0.417269
Percentage of Linear Algebra / Linear Transformations                                         0.381313
Percentage of Statistics                                                                      0.348566
Advanced Percentage                                                                           0.342783
Percentage of Complex Numbers                                                                 0.303303
Percentage of Fundamental Mathematics / Algebraic expressions, Equations, and Inequalities    0.169298
Percentage of Linear Algebra / Matrices and Determinants                                      0.147171
Percentage of Linear Algebra / Eigenvalues and Eigenvectors                                   0.147001
Percentage of Linear Algebra / Linear Systems                                                 0.143535
Percentage of Analytic Geometry                                                               0.138592
Percentage of Probability                                                                     0.126435
Country Code                                                                                  0.120778
Percentage of Optimization / Linear Optimization                                              0.119238
Percentage of Optimization / Nonlinear Optimization                                           0.118845
Percentage of Integration / Integration Techniques                                            0.106672
Percentage of Differentiation / Derivatives                                                   0.092840
Percentage of Real Functions of a single variable / Domain, Image and Graphics                0.086286
Percentage of Differentiation / Partial Differentiation                                       0.083795
Percentage of Differential Equations                                                          0.082613
Percentage of Fundamental Mathematics / Elementary Geometry                                   0.080440
Percentage of Graph Theory                                                                    0.048896
Percentage of Numerical Methods                                                               0.048247
Percentage of Real Functions of a single variable / Limits and Continuity                     0.042111
Percentage of Integration / Double Integration                                                0.030988
Percentage of Set Theory                                                                      0.022227
Percentage of Integration / Definite Integrals                                               -0.003051
Name: Percentage, dtype: float64
"""

# %%
# import everything
import pandas as pd
import shutil
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/usr/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
# ...

# %%
# Read the data
data = pd.read_csv("data.csv", sep=";", encoding="windows-1252")

# %%
data.head()
# Out:
#    Student ID Student Country  Question ID  Type of Answer Question Level  \
# 0         647         Ireland           77               0          Basic
# 1          41        Portugal           77               1          Basic
# 2         340        Portugal           77               1          Basic
# 3         641           Italy           77               0          Basic
# 4         669        Portugal           77               1          Basic
#
#         Topic    Subtopic                                           Keywords
# 0  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
# 1  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
# 2  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
# 3  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
# 4  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...

# %%
# Preprocess the data
data_dropped_duplicates = data.drop_duplicates()
lines_dropped = len(data) - len(data_dropped_duplicates)
percentage_dropped = int(lines_dropped / len(data) * 100)
dropped = data[data.duplicated(keep=False)]
data = data_dropped_duplicates
print(f"Dropped {lines_dropped} ({percentage_dropped}%) duplicates, such as:")
# Out:
# Dropped 2083 (21%) duplicates, such as:

# %%
dropped.head()
# Out:
#     Student ID Student Country  Question ID  Type of Answer Question Level  \
# 28          41        Portugal           79               1          Basic
# 29          41        Portugal           79               1          Basic
# 35          57        Portugal           79               0          Basic
# 36          57        Portugal           79               0          Basic
# 78         181           Italy           83               0          Basic
#
#                                   Topic                    Subtopic  \
# 28                           Statistics                  Statistics
# 29                           Statistics                  Statistics
# 35                           Statistics                  Statistics
# 36                           Statistics                  Statistics
# 78  Real Functions of a single variable  Domain, Image and Graphics
#
#                                              Keywords
# ...

# %%
null_counts = data.isnull().sum()
print(
    f"Found {null_counts.sum()} null values in the data, so we do not need to drop any."
)
# Out:
# Found 0 null values in the data, so we do not need to drop any.

# %%
# Get question topics
data["Topic Name"] = data.apply(
    lambda row: (
        row["Topic"]
        if row["Topic"] == row["Subtopic"]
        else f"{row['Topic']} / {row['Subtopic']}"
    ),
    axis=1,
)
topics = data.groupby("Topic Name")[["Topic", "Subtopic"]].first().reset_index()
topics["Question Count"] = (
    data.drop_duplicates("Question ID")["Topic Name"].value_counts().sort_index().values
)

# %%
# Print the topics
topics[["Topic", "Subtopic", "Topic Name", "Question Count"]]
# Out:
#                                   Topic  \
# 0                     Analytic Geometry
# 1                       Complex Numbers
# 2                Differential Equations
# 3                       Differentiation
# 4                       Differentiation
# 5               Fundamental Mathematics
# 6               Fundamental Mathematics
# 7                          Graph Theory
# 8                           Integration
# 9                           Integration
# 10                          Integration
# 11                       Linear Algebra
# 12                       Linear Algebra
# 13                       Linear Algebra
# 14                       Linear Algebra
# 15                       Linear Algebra
# 16                    Numerical Methods
# 17                         Optimization
# 18                         Optimization
# 19                         Probability
# 20  Real Functions of a single variable
# 21  Real Functions of a single variable
# ...

# %%
# Assign score to questions
data["Total Basic Score"] = data["Question Level"].eq("Basic").astype(int)
data["Total Advanced Score"] = data["Question Level"].eq("Advanced").astype(int)
data["Total Score"] = data["Total Basic Score"] + data["Total Advanced Score"]
data["Personal Basic Score"] = data["Total Basic Score"] * data["Type of Answer"]
data["Personal Advanced Score"] = data["Total Advanced Score"] * data["Type of Answer"]
data["Personal Score"] = data["Personal Basic Score"] + data["Personal Advanced Score"]
for i, row in topics.iterrows():
    topic_name = row["Topic Name"]
    total_column_name = "Total Score of " + topic_name
    personal_column_name = "Personal Score of " + topic_name
    data[total_column_name] = data["Total Score"] * data["Topic Name"].eq(topic_name)
    data[personal_column_name] = data[total_column_name] * data["Type of Answer"]

# %%
# Calculate the total score of each student
scores = (
    data.groupby("Student ID")[
        [
            "Total Basic Score",
            "Personal Basic Score",
            "Total Advanced Score",
            "Personal Advanced Score",
            "Total Score",
            "Personal Score",
        ]
        + ["Total Score of " + topic_name for topic_name in topics["Topic Name"]]
        + ["Personal Score of " + topic_name for topic_name in topics["Topic Name"]]
    ]
    .sum()
    .reset_index()
)
scores["Basic Percentage"] = (
    scores["Personal Basic Score"] / scores["Total Basic Score"] * 100
)
scores["Advanced Percentage"] = (
    scores["Personal Advanced Score"] / scores["Total Advanced Score"] * 100
)
scores["Percentage"] = scores["Personal Score"] / scores["Total Score"] * 100
for i, row in topics.iterrows():
    topic_name = row["Topic Name"]
    total_column_name = "Total Score of " + topic_name
    personal_column_name = "Personal Score of " + topic_name
    percentage_column_name = "Percentage of " + topic_name
    scores[percentage_column_name] = (
        scores[personal_column_name] / scores[total_column_name] * 100
    )

# %%
# Print the total score of each student
scores[["Student ID", "Percentage", "Basic Percentage", "Advanced Percentage"]].head()
# Out:
#    Student ID  Percentage  Basic Percentage  Advanced Percentage
# 0          26   72.463768         72.463768                  NaN
# 1          28   51.020408         51.020408                  NaN
# 2          36   51.428571         50.000000            57.142857
# 3          37   59.375000         57.264957            81.818182
# 4          41   56.896552         56.603774            60.000000

# %%
# Calculate max, min, quartiles, mean and std of the scores
def calculate_statistics(column: pd.Series):
    return pd.DataFrame(
        {
            "Max": column.max(),
            "Min": column.min(),
            "Q1": column.quantile(0.25),
            "Q2": column.quantile(0.5),
            "Q3": column.quantile(0.75),
            "Mean": column.mean(),
            "Std": column.std(),
        }
    )
percentage_column_names = ["Percentage", "Basic Percentage", "Advanced Percentage"] + [
    "Percentage of " + topic_name for topic_name in topics["Topic Name"]
]

# %%
calculate_statistics(scores[percentage_column_names])
# Out:
#                                                            Max        Min  \
# Percentage                                          100.000000   0.000000
# Basic Percentage                                    100.000000   0.000000
# Advanced Percentage                                 100.000000   0.000000
# Percentage of Analytic Geometry                     100.000000   0.000000
# Percentage of Complex Numbers                       100.000000   0.000000
# Percentage of Differential Equations                100.000000   0.000000
# Percentage of Differentiation / Derivatives          85.714286   0.000000
# Percentage of Differentiation / Partial Differe...  100.000000   0.000000
# Percentage of Fundamental Mathematics / Algebra...  100.000000   0.000000
# Percentage of Fundamental Mathematics / Element...  100.000000   0.000000
# Percentage of Graph Theory                          100.000000   0.000000
# Percentage of Integration / Definite Integrals       85.714286  62.500000
# ...

# %%
# Find outliers
def find_outliers(df: pd.DataFrame, column: str):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    return df[(df[column] < Q1 - 1.5 * IQR) | (df[column] > Q3 + 1.5 * IQR)]


for column in percentage_column_names:
    outliers = find_outliers(scores, column)
    if len(outliers) > 0:
        print(
            "--------------------------------------------------------------------------------"
        )
        print(f"Outliers in {column}:")
        Q1 = scores[column].quantile(0.25)
        Q3 = scores[column].quantile(0.75)
        IQR = Q3 - Q1
        all = scores[["Student ID", column]].dropna().sort_values(column)
        print(f"Q1 = {Q1:.2f}, Q3 = {Q3:.2f}, IQR = {IQR:.2f}, {len(all)} students")
        if column.startswith("Percentage of "):
            topic_name = column[len("Percentage of ") :]
            question_count = topics[topics["Topic Name"] == topic_name][
                "Question Count"
            ].iloc[0]
            print(f"{question_count} questions in {topic_name}")
        print(outliers[["Student ID", column]].sort_values(column))
        print("All students:")
        print(all)
        print(
            "--------------------------------------------------------------------------------"
        )
    else:
        print(f"(No outliers in {column}.)")
# Out:
# (No outliers in Percentage.)
# (No outliers in Basic Percentage.)
# (No outliers in Advanced Percentage.)
# (No outliers in Percentage of Analytic Geometry.)
# (No outliers in Percentage of Complex Numbers.)
# (No outliers in Percentage of Differential Equations.)
# (No outliers in Percentage of Differentiation / Derivatives.)
# --------------------------------------------------------------------------------
# Outliers in Percentage of Differentiation / Partial Differentiation:
# Q1 = 0.00, Q3 = 23.75, IQR = 23.75, 30 students
# 55 questions in Differentiation / Partial Differentiation
#     Student ID  Percentage of Differentiation / Partial Differentiation
# 3           37                                          65.625000
# 23         155                                          66.666667
# 97         483                                          75.000000
# 0           26                                         100.000000
# ...

# %%
# Find relationship between country and score

# Merge country with scores
student_and_country = (
    data.groupby("Student ID")["Student Country"].first().reset_index()
)
score_and_country = pd.merge(scores, student_and_country, on="Student ID")
print(score_and_country.head())

# Encode country
label_encoder = LabelEncoder()
label_encoder.fit(score_and_country["Student Country"])
score_and_country["Country Code"] = label_encoder.transform(
    score_and_country["Student Country"]
)

# Fill NaN in percentages
for column in percentage_column_names:
    score_and_country[column] = score_and_country[column].fillna(
        scores[column].quantile(0.5)
    )
percentages = score_and_country[percentage_column_names]

# Do not need to scale the data because the percentages are already in the same range

# Use PCA to reduce the dimensionality of the data
pca = PCA(n_components=2)
pca.fit(percentages[percentage_column_names])
percentages_pca = pca.transform(percentages[percentage_column_names])

# Use T-SNE to reduce the dimensionality of the data
tsne = TSNE(n_components=2)
percentages_tsne = tsne.fit_transform(percentages[percentage_column_names])


# Plot the data
def plot_points_by_country(ndarr, x: str, y: str, title: str, filename: str):
    plt.figure(figsize=(10, 10))
    for i, country in enumerate(label_encoder.classes_):
        country_indices = score_and_country["Country Code"] == i
        plt.scatter(
            ndarr[country_indices, 0],
            ndarr[country_indices, 1],
            label=country,
        )
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(title)
    plt.legend()
    plt.savefig("images/" + filename)


def plot_curve_by_country(ndarr, y: str, title: str, filename: str):
    plt.figure(figsize=(10, 10))
    for i, country in enumerate(label_encoder.classes_):
        country_indices = score_and_country["Country Code"] == i
        sns.kdeplot(ndarr[country_indices], label=country)
    plt.xlabel("Density")
    plt.ylabel(y)
    plt.title(title)
    plt.legend()
    plt.savefig("images/" + filename)


plot_points_by_country(
    scores[["Total Score", "Percentage"]].to_numpy(),
    "Total Score",
    "Percentage",
    "Student Scores by Total Score and country",
    "percentage_total.png",
)
plot_curve_by_country(
    percentages["Percentage"],
    "Percentage",
    "Density of Student Scores by Country",
    "percentage_density.png",
)
plot_points_by_country(
    percentages_pca,
    "Principle Component 1",
    "Principle Component 2",
    "PCA of Student Scores by Country",
    "percentage_pca.png",
)
plot_points_by_country(
    percentages_tsne,
    "T-SNE Component 1",
    "T-SNE Component 2",
    "T-SNE of Student Scores by Country",
    "percentage_tsne.png",
)
# Out:
#    Student ID  Total Basic Score  Personal Basic Score  Total Advanced Score  \
# 0          26                 69                    50                     0
# 1          28                 49                    25                     0
# 2          36                 28                    14                     7
# 3          37                117                    67                    11
# 4          41                 53                    30                     5
#
#    Personal Advanced Score  Total Score  Personal Score  \
# 0                        0           69              50
# 1                        0           49              25
# 2                        4           35              18
# 3                        9          128              76
# 4                        3           58              33
#
#    Total Score of Analytic Geometry  Total Score of Complex Numbers  \
# 0                                22                               0
# ...

# %%
# Calculate correlations

score_and_country[
    [
        "Personal Score",
        "Personal Basic Score",
        "Personal Advanced Score",
        "Country Code",
    ]
].corr()
# Out:
#                          Personal Score  Personal Basic Score  \
# Personal Score                 1.000000              0.951842
# Personal Basic Score           0.951842              1.000000
# Personal Advanced Score        0.631442              0.363297
# Country Code                   0.021222              0.013948
#
#                          Personal Advanced Score  Country Code
# Personal Score                          0.631442      0.021222
# Personal Basic Score                    0.363297      0.013948
# Personal Advanced Score                 1.000000      0.029215
# Country Code                            0.029215      1.000000

# %%
score_and_country[["Country Code"] + percentage_column_names].corr()["Percentage"].sort_values(ascending=False)
# Out:
# Percentage                                                                                    1.000000
# Basic Percentage                                                                              0.916512
# Percentage of Linear Algebra / Vector Spaces                                                  0.417269
# Percentage of Linear Algebra / Linear Transformations                                         0.381313
# Percentage of Statistics                                                                      0.348566
# Advanced Percentage                                                                           0.342783
# Percentage of Complex Numbers                                                                 0.303303
# Percentage of Fundamental Mathematics / Algebraic expressions, Equations, and Inequalities    0.169298
# Percentage of Linear Algebra / Matrices and Determinants                                      0.147171
# ...

# %%
# Grouping students

# Standardize the data
scaler = StandardScaler()
scaler_score_and_country = scaler.fit_transform(
    score_and_country[["Country Code"] + percentage_column_names]
)

# Use KNN to group students
k = 5
kmeans = KMeans(n_clusters=k)
kmeans.fit(scaler_score_and_country)
score_and_country["KNN Group"] = kmeans.labels_


# Use decision tree to group students
decision_tree = DecisionTreeClassifier(max_depth=3)
decision_tree.fit(scaler_score_and_country, score_and_country["KNN Group"])
score_and_country["Decision Tree Group"] = decision_tree.predict(
    scaler_score_and_country
)

# Use SVC to group students
svc = SVC()
svc.fit(scaler_score_and_country, score_and_country["KNN Group"])
score_and_country["SVC Group"] = svc.predict(scaler_score_and_country)


# Plot groups
def plot_groups(
    ndarr, k: int, group_name: str, x: str, y: str, title: str, filename: str
):
    plt.figure(figsize=(10, 10))
    for i in range(k):
        group_indices = score_and_country[group_name] == i
        plt.scatter(
            ndarr[group_indices, 0],
            ndarr[group_indices, 1],
            label=f"Group {i}",
        )
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(title)
    plt.legend()
    plt.savefig("images/" + filename)


plot_groups(
    percentages_pca,
    k,
    "KNN Group",
    "Principle Component 1",
    "Principle Component 2",
    "PCA of Student Scores by KNN Group",
    "group_knn_pca.png",
)
plot_groups(
    percentages_tsne,
    k,
    "KNN Group",
    "T-SNE Component 1",
    "T-SNE Component 2",
    "T-SNE of Student Scores by KNN Group",
    "group_knn_tsne.png",
)
plot_groups(
    percentages_pca,
    decision_tree.classes_.size,
    "Decision Tree Group",
    "Principle Component 1",
    "Principle Component 2",
    "PCA of Student Scores by Decision Tree Group",
    "group_decision_tree_pca.png",
)
plot_groups(
    percentages_tsne,
    decision_tree.classes_.size,
    "Decision Tree Group",
    "T-SNE Component 1",
    "T-SNE Component 2",
    "T-SNE of Student Scores by Decision Tree Group",
    "group_decision_tree_tsne.png",
)
plot_groups(
    percentages_pca,
    svc.classes_.size,
    "SVC Group",
    "Principle Component 1",
    "Principle Component 2",
    "PCA of Student Scores by SVC Group",
    "group_svc_pca.png",
)
plot_groups(
    percentages_tsne,
    svc.classes_.size,
    "SVC Group",
    "T-SNE Component 1",
    "T-SNE Component 2",
    "T-SNE of Student Scores by SVC Group",
    "group_svc_tsne.png",
)
